# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#     color         shape fruitname  eat
# 0  yellow         round     mango  yes
# 1  yellow  cylinderical    banana   no
# 2     red         round     apple  yes
# 3  yellow         round     lemon  yes

# %%
concepts = np.array(data)[:,:-1]

# %%
concepts
# Out:
# array([['yellow', 'round', 'mango'],
#        ['yellow', 'cylinderical', 'banana'],
#        ['red', 'round', 'apple'],
#        ['yellow', 'round', 'lemon']], dtype=object)

# %%
target = np.array(data)[:,-1]

# %%
target
# Out:
# array(['yes', 'no', 'yes', 'yes'], dtype=object)

# %%
def train(con, tar):
    for i, val in enumerate(tar):
        if val == 'yes':
            specific_h = con[i].copy()
            break
            
    for i, val in enumerate(con):
        if tar[i] == 'yes':
            for x in range(len(specific_h)):
                if val[x] != specific_h[x]:
                    specific_h[x] = '?'
                else:
                    pass
    return specific_h

# %%
print(train(concepts, target))
# Out:
# ['?' 'round' '?']
